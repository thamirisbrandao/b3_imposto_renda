# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

table = pd.read_html('../raw_data/U4048858_2020_2020.htm')

# %%
table
# Out:
# [                      0                 1
#  0                  Name  Rafael S Camargo
#  1               Account          U4048858
#  2          Account Type        Individual
#  3         Customer Type        Individual
#  4  Account Capabilities              Cash
#  5         Base Currency               USD,
#               Unnamed: 0_level_0             December 31, 2019  \
#               Unnamed: 0_level_1                         Total
#  0                          Cash                          0.00
#  1                         Stock                          0.00
#  2             Dividend Accruals                          0.00
#  3                         Total                          0.00
#  4                           NaN                           NaN
#  5  Time Weighted Rate of Return  Time Weighted Rate of Return
#
#                December 31, 2020                                \
#                             Long                         Short
# ...
